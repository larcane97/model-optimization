# %%
import torch
from src.augmentation.dataset import CustomNoisyStudentTrainingDataset
import matplotlib.pyplot as plt

# %%
dataset = CustomNoisyStudentTrainingDataset()
# Out:
# /opt/conda/envs/lightweight/lib/python3.7/site-packages/albumentations/augmentations/transforms.py:967: FutureWarning: This class has been deprecated. Please use ImageCompression
#   FutureWarning,

# %%
import numpy as np

idx = np.random.randint(0,len(dataset))
[data,aug] = dataset[idx]
data = (data*0.2)+0.5
aug = (aug*0.2)+0.5
fig,axes = plt.subplots(1,2, figsize=(9,12))
axes[0].imshow(data.permute(1,2,0))
axes[1].imshow(aug.permute(1,2,0))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import optuna
